# %% [markdown]
# # Homework	Assignment	4 – Linear	Programming

# %% [markdown]
# ## BACKGROUND

# %% [markdown]
# A	chain	of	restaurants	has	requested	a	very	familiar	chef	to	prepare	salads	and
# pizzas.
#
# For	ingredients,	the	chef has 67500 grams of	cheese and 90000 grams of	tomatoes.
#
# • Every	salad needs 90 grams of	cheese and 180 grams	of	tomatoes.
#
# • Every	pizza needs 360 grams	of	cheese	and	90 grams	of	tomatoes.
#
# The	price	of	the	salad is	fixed	at	$20 and	the	pizza,	$22.	What	is	the	number	of	salads
# and	pizzas that	the	chef	must	prepare	for restaurants so	that	these	items	obtain	a
# maximum	sale?

# %% [markdown]
# ### TASK	1:	UNDERSTAND	THE	PROBLEM

# %% [markdown]
# ### 1. Write	in	your	own	words	what	is	the	objective	function (Provide	a	verbal	answer,	 no	calculations	needed).

# %% [markdown]
# The objective function in this problem is to maximize the sales revenue generated by the salads and pizzas prepared by the chef.
#
# The objective function can be expressed as follows:
# Maximize: 20x + 22y
#
# Where:
# x = Number of salads prepared
# y = Number of pizzas prepared

# %% [markdown]
# ### 2. Write	in	your	own	words	what	are	the	decision	variables	(Provide	a	verbal	answer,	no	calculations	needed).

# %% [markdown]
# The decision variables in this problem are the quantities of salads and pizzas that the chef must prepare. We need to determine how many salads (x) and how many pizzas (y) should be made in order to maximize the sales revenue. These variables represent the choices the chef can make in terms of the number of each item to produce.

# %% [markdown]
# ### 3. Write	in	your	own	words	what	are	the	constraints	(Provide	a	verbal	answer,	no calculations	needed).

# %% [markdown]
# a. Cheese constraint: 90x + 360y ≤ 67,500
# b. Tomato constraint: 180x + 90y ≤ 90,000
# c. Non-negativity constraint: x ≥ 0, y ≥ 0

# %% [markdown]
# ## TASK	2:	SOLVE	THE	PROBLEM	GRAPHICALLY

# %% [markdown]
# the answers in an ipad note
